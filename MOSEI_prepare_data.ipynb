# %% [markdown]
# # Use CMU-Multimodal-SDK to Obtain Dataset #
#
# ### First install the SDK by running: ###
#
# ```console
# git clone https://github.com/CMU-MultiComp-Lab/CMU-MultimodalSDK.git
#
# cd CMU-MultiModalSDK
# pip install .
# ```
#
#
# Change the `SDK_PATH` variable in `constants/paths.py` to reflect the directory you just created.

# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys

if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)

import mmsdk
import os
import re
import numpy as np
from mmsdk import mmdatasdk as md
from subprocess import check_call, CalledProcessError

# create folders for storing the data
if not os.path.exists(DATA_PATH):
    check_call(' '.join(['mkdir', '-p', DATA_PATH]), shell=True)

# download highlevel features, low-level (raw) data and labels for the dataset MOSEI
# if the files are already present, instead of downloading it you just load it yourself.

DATASET = md.cmu_mosei

try:
    md.mmdataset(DATASET.highlevel, DATA_PATH)
except RuntimeError:
    print("High-level features have been downloaded previously.")

try:
    md.mmdataset(DATASET.raw, DATA_PATH)
except RuntimeError:
    print("Raw data have been downloaded previously.")
    
try:
    md.mmdataset(DATASET.labels, DATA_PATH)
except RuntimeError:
    print("Labels have been downloaded previously.")
# Out:
# [2024-04-20 13:35:54.126] | Error   | ./data/CMU_MOSEI_TimestampedWordVectors.csd file already exists ...
# High-level features have been downloaded previously.
# [2024-04-20 13:35:55.282] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/language/CMU_MOSEI_TimestampedWords.csd to ./data/CMU_MOSEI_TimestampedWords.csd...
# [2024-04-20 13:36:01.751] | Success | Download complete!
# [2024-04-20 13:36:01.780] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWords.csd ...
# [2024-04-20 13:36:01.975] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-04-20 13:36:01.975] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-04-20 13:36:02.614] | Success | <words> computational sequence data in correct format.
# [2024-04-20 13:36:02.614] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-04-20 13:36:02.614] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 13:36:02.704] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/language/CMU_MOSEI_TimestampedPhones.csd to ./data/CMU_MOSEI_TimestampedPhones.csd...
# [2024-04-20 13:36:11.273] | Success | Download complete!
# [2024-04-20 13:36:11.275] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedPhones.csd ...
# [2024-04-20 13:36:11.322] | Status  | Checking the integrity of the <phoneme> computational sequence ...
# [2024-04-20 13:36:11.322] | Status  | Checking the format of the data in <phoneme> computational sequence ...
# [2024-04-20 13:36:12.007] | Success | <phoneme> computational sequence data in correct format.
# [2024-04-20 13:36:12.007] | Status  | Checking the format of the metadata in <phoneme> computational sequence ...
# [2024-04-20 13:36:12.007] | Warning | <phoneme> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 13:36:12.007] | Success | Dataset initialized successfully ...
# [2024-04-20 13:36:12.143] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/labels/CMU_MOSEI_Labels.csd to ./data/CMU_MOSEI_Labels.csd...
# [2024-04-20 13:36:15.771] | Success | Download complete!
# [2024-04-20 13:36:15.772] | Success | Computational sequence read from file ./data/CMU_MOSEI_Labels.csd ...
# [2024-04-20 13:36:15.816] | Status  | Checking the integrity of the <All Labels> computational sequence ...
# [2024-04-20 13:36:15.816] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2024-04-20 13:36:16.288] | Success | <All Labels> computational sequence data in correct format.
# [2024-04-20 13:36:16.288] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2024-04-20 13:36:16.288] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 13:36:16.288] | Success | Dataset initialized successfully ...

# %%
# list the directory contents (should see .csd files which are computational sequences)
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# CMU_MOSEI_TimestampedWordVectors.csd
# CMU_MOSEI_COVAREP.csd
# CMU_MOSEI_TimestampedPhones.csd
# CMU_MOSEI_TimestampedWords.csd
# CMU_MOSEI_Labels.csd

# %% [markdown]
# ## Load the Dataset: ##
#
# Create a recipe (dictionary of the form `{feature_name: csd_path}`) and feed it into a `mmdataset` object

# %%
# define the modalities we want
acoustic_field = 'CMU_MOSEI_COVAREP'
text_field = 'CMU_MOSEI_TimestampedWords'


features = [
    text_field, 
    acoustic_field
]

recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}
dataset = md.mmdataset(recipe)
# Out:
# [2024-04-20 13:36:34.146] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWords.csd ...
# [2024-04-20 13:36:34.534] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-04-20 13:36:34.534] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-04-20 13:36:35.105] | Success | <words> computational sequence data in correct format.
# [2024-04-20 13:36:35.105] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-04-20 13:36:35.105] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 13:36:35.105] | Success | Computational sequence read from file ./data/CMU_MOSEI_COVAREP.csd ...
# [2024-04-20 13:36:35.395] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-04-20 13:36:35.396] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-04-20 13:36:36.518] | Success | <COVAREP> computational sequence data in correct format.
# [2024-04-20 13:36:36.518] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-04-20 13:36:36.518] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 13:36:36.518] | Success | Dataset initialized successfully ...

# %%
dataset[acoustic_field][some_id]

# %%
print(list(dataset.keys()))
print("=" * 80)

print(list(dataset[acoustic_field].keys())[:10])
print("=" * 80)

some_id = list(dataset[acoustic_field].keys())[15]
print(list(dataset[acoustic_field][some_id].keys()))
print("=" * 80)

print(list(dataset[acoustic_field][some_id]['intervals'].shape))
print("=" * 80)

print(list(dataset[acoustic_field][some_id]['features'].shape))
print(list(dataset[text_field][some_id]['features'].shape))
# Out:
# ['CMU_MOSEI_TimestampedWords', 'CMU_MOSEI_COVAREP']
# ================================================================================
# ['--qXJuDtHPw[0]', '--qXJuDtHPw[1]', '--qXJuDtHPw[2]', '--qXJuDtHPw[3]', '--qXJuDtHPw[4]', '--qXJuDtHPw[5]', '--qXJuDtHPw[6]', '--qXJuDtHPw[7]', '--qXJuDtHPw[8]', '--qXJuDtHPw[9]']
# ================================================================================
# ['intervals', 'features']
# ================================================================================
# [1, 2]
# ================================================================================
# [1, 74]
# [1, 1]

# %% [markdown]
# ### Different modalities have different number of time steps. We need to align them to a single modality. ###

# %% [markdown]
# ## Align the Dataset to a Single Modality (Words) ##
#
# Create a `collapse_function` that averages the features so that all modalities can be aligned to a single shape

# %%
# Define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features

# Align the dataset to the textual modality with averaging, collapse_function receives a list of functions
dataset.align(text_field, collapse_functions=[avg])
# Out:
# [2024-04-20 14:03:08.696] | Status  | Unify was called ...
# [2024-04-20 14:03:08.701] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-04-20 14:03:08.709] | Success | Unify completed ...
# [2024-04-20 14:03:08.709] | Status  | Pre-alignment based on <CMU_MOSEI_TimestampedWords> computational sequence started ...
# [2024-04-20 14:06:10.002] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-04-20 14:06:15.346] | Status  | Alignment starting ...
# [2024-04-20 14:17:26.676] | Success | Alignment to <CMU_MOSEI_TimestampedWords> complete.
# [2024-04-20 14:17:26.677] | Status  | Replacing dataset content with aligned computational sequences
# [2024-04-20 14:17:27.152] | Success | Initialized empty <CMU_MOSEI_TimestampedWords> computational sequence.
# [2024-04-20 14:17:27.152] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-04-20 14:17:31.086] | Success | <CMU_MOSEI_TimestampedWords> computational sequence data in correct format.
# [2024-04-20 14:17:31.086] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-04-20 14:17:31.089] | Warning | <CMU_MOSEI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 14:17:31.089] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-04-20 14:17:31.089] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-04-20 14:17:31.846] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-04-20 14:17:31.846] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-04-20 14:17:31.846] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing

# %%
# check out what the keys look like now (there is an added segment no in the str key)
print(list(dataset[text_field].keys())[55])
# Out:
# --qXJuDtHPw[55]

# %% [markdown]
# ##  Append Annotations (Labels) to the Dataset ##

# %%
label_field = 'CMU_MOSEI_Labels'

# add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(DATA_PATH, label_field + '.csd')}
computational sequence does not have all the required metadata ... continuing
# [2024-04-20 14:31:03.196] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-04-20 14:31:03.196] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-04-20 14:31:03.217] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-04-20 14:31:03.217] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-04-20 14:31:03.217] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-04-20 14:31:03.217] | Success | Initialized empty <CMU_MOSEI_Labels> computational sequence.
# [2024-04-20 14:31:03.217] | Status  | Checking the format of the data in <CMU_MOSEI_Labels> computational sequence ...
# [2024-04-20 14:31:03.243] | Success | <CMU_MOSEI_Labels> computational sequence data in correct format.
# [2024-04-20 14:31:03.243] | Status  | Checking the format of the metadata in <CMU_MOSEI_Labels> computational sequence ...
# [2024-04-20 14:31:03.243] | Warning | <CMU_MOSEI_Labels> computational sequence does not have all the required metadata ... continuing

# %%
print(list(dataset[text_field].keys())[55])
# Out:
# -HwX2H8Z4hY[4]

# %% [markdown]
# ## Split the Dataset ##
#
# Use the standard/provided train, test, and dev splits but extract the `segment no.` (see example key in cell above) using regex

# %%
# Train/Dev/Test splits (based on video IDs)
train_split = DATASET.standard_folds.standard_train_fold
dev_split = DATASET.standard_folds.standard_valid_fold
test_split = DATASET.standard_folds.standard_test_fold

# Splits only contain video IDs (i.e. we need to append the segment no. as well)
print(test_split)
# Out:
# ['7l3BNtSE0xc', 'dZFV0lyedX4', '286943', '126872', 'qgC8_emxSIU', 'kld9r0iFkWM', 'rC29Qub0U7A', '4YfyP0uIqw0', 'FMenDv3y8jc', '4wLP4elp1uM', 'KYQTwFVBzME', '27v7Blr0vjw', 'DnBHq5I52LM', 'HR18U0yAlTc', 'x266rUJQC_8', 'd1CDP6sMuLA', 'xSCvspXYU9k', '4EDblUpJieU', '4o4ilPK9rl8', '53609', 'SZ7HK5ns6mE', '243981', 'ySblgk7T7eQ', 'MYEyQUpMe3k', 'EujJ0SwiCRE', '3HyAaqre_Fk', 'iQDB_OkAQWs', 'gE7kUqMqQ9g', 'eFV7iFPYZB4', 'IRSxo_XXArg', '3hOlJf_JQDs', 'BRSyH6yfDLk', '1jogeKX0wGw', '3At-BKm9eYk', 'NVLPURuAVLU', 'pZye4zFzk3o', 'l1jW3OMXUzs', 'XKyumlBmix8', 'eKQKEi2-0Ws', 'WgI8IbJtXHw', 'tnWmVXZ87h0', 'YCEllKyaCrc', 'W1CWpktWtTs', '8wQhzezNcUY', '0bxhZ-LIfZY', 'lrjm6F3JJgg', 'Vdf1
torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
from collections import defaultdict

# a sentinel epsilon for safe division, without it we will replace illegal values with a constant
EPS = 0

# construct a word2id mapping that automatically takes increment when new words are encountered
word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']

# place holders for the final train/dev/test dataset splits
train = []
dev = []
test = []

# define a regular expression to extract the video ID out of the keys (e.g. )
pattern = re.compile('(.*)\[.*\]')
num_drop = 0 # a counter to count how many data points went into some processing issues

for segment in dataset[label_field].keys():
    
    # get the video ID and the features out of the aligned dataset
    vid = re.search(pattern, segment).group(1)
    label = dataset[label_field][segment]['features']
    _words = dataset[text_field][segment]['features']
    _acoustic = dataset[acoustic_field][segment]['features']

    # if the sequences are not same length after alignment, there must be some problem with some modalities
    # we should drop it or inspect the data again
    if not _words.shape[0] == _acoustic.shape[0]:
        print(f"Encountered datapoint {vid} with text shape {_words.shape}, acoustic shape {_acoustic.shape}")
        num_drop += 1
        continue

    # remove nan values
    label = np.nan_to_num(label)
    _acoustic = np.nan_to_num(_acoustic)

    # remove speech pause tokens - this is in general helpful
    # we should remove speech pauses and corresponding acoustic features together
    # otherwise modalities would no longer be aligned
    words = []
    acoustic = []
    for i, word in enumerate(_words):
        if word[0] != b'sp':
            words.append(word2id[word[0].decode('utf-8')]) # SDK stores strings as bytes, decode into strings here
            acoustic.append(_acoustic[i, :])

    words = np.asarray(words)
    acoustic = np.asarray(acoustic)

    # z-normalization per instance and remove nan/infs
    acoustic = np.nan_to_num((acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))

    if vid in train_split:
        train.append(((word, acoustic), label, segment))
    elif vid in dev_split:
        dev.append(((words, acoustic), label, segment))
    elif vid in test_split:
        test.append(((words, acoustic), label, segment))
    else:
        print(f"Found video that doesn't belong to any splits: {vid}")

print(f"Total number of {num_drop} datapoints have been dropped.")

# turn off the word2id - define a named function here to allow for pickling
def return_unk():
    return UNK
word2id.default_factory = return_unk
# Out:
# /var/folders/y4/h92v27td7m1_v78ms19qrfvw0000gn/T/ipykernel_24086/3535779963.py:61: RuntimeWarning: invalid value encountered in divide
#   acoustic = np.nan_to_num((acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))
# /opt/homebrew/anaconda3/envs/deep_learning/lib/python3.11/site-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /opt/homebrew/anaconda3/envs/deep_learning/lib/python3.11/site-packages/numpy/core/_methods.py:118: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /opt/homebrew/anaconda3/envs/deep_learning/lib/python3.11/site-packages/numpy/core/_methods.py:152: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Eqdz5y4pEY
# Found video that doesn't belong to any splits: -HvKLjmsO5U
# Found video that doesn't belong to any splits: -HvKLjmsO5U
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IqSFQePnpU
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -cmk6cfUeMs
# Found video that doesn't belong to any splits: -cmk6cfUeMs
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -l_53IwQoj0
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -o_667Ny7RM
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -wdUIwjDMfg
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 4Y8ROYezksQ
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 6ywl-j2-e-s
# Found video that doesn't belong to any splits: 6ywl-j2-e-s
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AcoRjVPIVmQ
# Found video that doesn't belong to any splits: AcoRjVPIVmQ
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EuSp1pkX9i8
# Found video that doesn't belong to any splits: EuSp1pkX9i8
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: ptp-kfn4vWY
# Found video that doesn't belong to any splits: ptp-kfn4vWY
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: slz8pd0Wzxs
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Total number of 0 datapoints have been dropped.

# %% [markdown]
# ## Inspect the dataset: ##

# %%
# let's see the size of each set and shape of data
print(len(train))
print(len(dev))
print(len(test))

print(train[0][0][1].shape)
print(train[0][1].shape)
print(train[0][1])

print(f"Total vocab size: {len(word2id)}")

print(word2id.keys())
# Out:
# 16327
# 1871
# 4662
# (42, 74)
# (1, 7)
# [[1.        0.6666667 0.6666667 0.        0.        0.        0.6666667]]
# Total vocab size: 16825
# dict_keys(['<unk>', '<pad>', 'writer', 'i', 'see', 'that', 'a', 'is', 'somebody', 'who', 'has', 'an', 'incredible', 'command', 'of', 'mechanics', 'the', 'english', 'language', 'key', 'part', 'people', 'we', 'use', 'to', 'solve', 'those', 'issues', 'whether', "it's", 'stretch', 'or', 'outdoor', 'resistance', 'abrasions', 'different', 'technical', 'aspects', 'really', 'need', 'get', 'into', 'new', 'markets', "they've", 'been', 'able', 'bring', 'solutions', 'businesses', 'do', 'find', 'at', 'least', 'some', 'answers', 'table', 'operations', 'polymer', 'brings', 'aspect', 'our', 'operation', "don't", 'have', 'internally', "we're", 'huge', 'user', 'adhesives', 'for', 'called', 'flocking', 'and', 'inside', 'compounding', 'expertise', 'these', 'types', 'things', 'business', 'on', 'potentials', 'even', 'equipment', 'how', 'run', 'operate', 'with', 'pretty', 'big', 'long', 'experience', 'their', 'team', 'many', 'opportunities', 'through', 'way', 'changed', 'years', 'looking', 'niche', 'high', 'end', 'value', 'added', 'products', 'introduction', 'speaker', 'dr', 'erma', 'jean', 'sims', 'sonoma', 'state', 'university', 'my', 'name', "i'm", 'member', 'faculty', 'school', 'education', 'important', 'teachers', 'understand', 'legal', 'ethical', 'professional', 'obligations', 'in', 'educational', 'setting', 'noncompliance', 'can', 'result', 'liability', 'you', 'district', 'which', 'are', 'employed', 'this', 'rhett', 'reiger', 'white', 'caspian', 'studios', 'behalf', 'expert', 'village', 'want', 'create', 'however', 'again', 'low', 'budget', 'film', "there's", 'not', 'often', 'money', 'pay', 'crew', 'go', 'out', 'now', 'hopefully', 'was', 'so', 'very', 'locations', 'walk', 'around', 'talk', 'owners', 'if', 'tell', 'them', 'what', "you're", 'doing', 'build', 'little', 'excitement', 'put', 'glitz', 'there', 'let', 'everybody', 'knows', 'valuable', 'spot', 'going', 'future', 'retirement', 'ultimately', 'turned', 'income', 'when', 'no', 'longer', 'fully', 'retired', 'aware', 'until', 'they', 'be', 'older', 'age', 'realize', 'gosh', 'wasted', 'lot', 'time', 'placing', 'bets', 'stock', "that's", 'lost', 'answer', 'question', 'contribute', 'ira', 'absolutely', 'correct', 'but', 'always', 'mindful', 'security', 'your', 'using', 'it', 'make', 'sure', 'safe', 'financial', 'approval', 'ratings', 'gonna', 'post', 'yourself', 'golfing', 'more', 'accurate', 'laughter', 'applause', 'yet', 'he', 'happy', 'swallow', "he's", 'eat', 'golf', 'ball', 'replace', 'like', 'friend', 'only', 'one', 'song', 'guitar', 'drunk', 'wants', 'hear', 'tuning', 'up', 'republicans', 'pushing', 'bill', 'ways', 'radical', 'than', 'previous', 'bills', 'say', 'hey', 'baby', 'skin', 'soft', 'any', 'hair', 'face', 'nice', 'by', 'giving', 'good', 'example', 'directly', 'comparing', 'lady', 'hinting', 'her', 'remove', 'mustache', 'lastly', 'bitch', 'seen', 'us', 'bad', 'look', 'never', 'call', 'another', 'women', 'better', 'word', 'excuse', 'me', 'ms', 'mam', 'decent', 'polite', 'perfect', 'soul', 'mate', 'therapy', 'brush', 'gentle', 'ph', 'balanced', 'containing', 'fruit', 'oils', 'bamboo', 'prickly', 'bear', 'extracts', 'deliver', 'intense', 'healing', 'while', 'smooth', 'granules', 'buff', 'away', 'dead', 'dry', 'cells', "what's", 'wanted', 'video', 'about', 'hero', 'got', 'announced', 'today', 'live', 'will', 'coming', 'fall', 'sometime', 'lets', 'details', 'revealed', 'other', 'thing', "you'll", 'notice', 'trailer', 'crowds', 'venues', 'think', 'real', 'venue', 'play', 'just', 'stems', 'each', 'guys', 'game', 'full', 'band', 'drums', 'microphone', 'as', 'well', 'activision', "hasn't", 'said', 'old', 'work', 'instruments', 'behind', 'e', 'released', "doesn't", 'appear', 'licensed', 'gibson', 'fender', "we've", 'past', 'rumours', 'tend', 'bought', "won't", 'because', 'peripheral', 'would', 're', 'chart', 'all', 'songs', 'somehow', 'interact', 'same', 'guitars', 'tv', 'basically', 'music', 'network', 'allows', 'players', 'drop', 'themed', 'channels', 'far', 'bands', 'reported', 'accor ...

# %% [markdown]
# ## PyTorch DataLoader Functions: ##

# %%
def multi_collate(batch):
    '''
    Collate functions assume batch = [Dataset[i] for i in index_set]
    '''
    # for later use we sort the batch in descending order of length
    batch = sorted(batch, key=lambda x: x[0][0].shape[0], reverse=True)
    
    # get the data out of the batch - pad text & speech sequences to be of uniform length
    labels = torch.cat([torch.from_numpy(sample[1]) for sample in batch], dim=0)
    sentences = pad_sequence([torch.LongTensor(sample[0][0]) for sample in batch], padding_value=PAD)
    acoustic = pad_sequence([torch.FloatTensor(sample[0][1]) for sample in batch])
    
    # lengths are useful later in using RNNs
    lengths = torch.LongTensor([sample[0][0].shape[0] for sample in batch])
    return sentences, acoustic, labels, lengths

# construct dataloaders
batch_size = 32
train_loader = DataLoader(train, shuffle=True, batch_size=batch_size, collate_fn=multi_collate)
dev_loader = DataLoader(dev, shuffle=False, batch_size=batch_size, collate_fn=multi_collate)
test_loader = DataLoader(test, shuffle=False, batch_size=batch_size, collate_fn=multi_collate)

# create a temp dataloader to see batch shape
temp_loader = iter(DataLoader(test, shuffle=True, batch_size=8, collate_fn=multi_collate))
batch = next(temp_loader)

print(batch[0].shape) # word vectors, padded to maxlen
print(batch[1].shape) # acoustic features
print(batch[2]) # labels
print(batch[3]) # lengths
# Out:
# torch.Size([54, 8])
# torch.Size([54, 8, 74])
# tensor([[ 0.0000,  0.0000,  0.3333,  0.0000,  0.0000,  0.0000,  0.0000],
#         [-1.3333,  0.0000,  0.0000,  0.3333,  0.0000,  0.3333,  0.0000],
#         [ 2.6667,  2.6667,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.6667,  0.3333,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 1.0000,  0.3333,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [-0.3333,  0.0000,  1.0000,  0.0000,  0.0000,  1.3333,  1.0000],
#         [-3.0000,  0.0000,  0.0000,  1.3333,  0.0000,  0.3333,  0.0000],
#         [-0.3333,  0.0000,  0.3333,  0.3333,  0.0000,  0.3333,  0.3333]])
# tensor([54, 43, 39, 32, 27, 21, 17, 14])

# %%
# Let's actually inspect the transcripts to ensure it's correct
id2word = {v:k for k, v in word2id.items()}
examine_target = train
idx = np.random.randint(0, len(examine_target))
print(' '.join(list(map(lambda x: id2word[x], examine_target[idx][0][0].tolist()))))
# print(' '.join(examine_target[idx][0]))
print(examine_target[idx][1])
print(examine_target[idx][2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 5
#       3 examine_target = train
#       4 idx = np.random.randint(0, len(examine_target))
# ----> 5 print(' '.join(list(map(lambda x: id2word[x], examine_target[idx][0][0].tolist()))))
#       6 # print(' '.join(examine_target[idx][0]))
#       7 print(examine_target[idx][1])
#
# Cell In[62], line 5, in <lambda>(x)
#       3 examine_target = train
#       4 idx = np.random.randint(0, len(examine_target))
# ----> 5 print(' '.join(list(map(lambda x: id2word[x], examine_target[idx][0][0].tolist()))))
#       6 # print(' '.join(examine_target[idx][0]))
#       7 print(examine_target[idx][1])
#
# KeyError: b'sp'
